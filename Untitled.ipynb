# %%
from equilibrator_api import ComponentContribution, Q_
cc = ComponentContribution()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-0e6d65fe33b0> in <module>
#       1 from equilibrator_api import ComponentContribution, Q_
# ----> 2 cc = ComponentContribution()
#
# ~/anaconda3/lib/python3.8/site-packages/equilibrator_api/component_contribution.py in __init__(self, rmse_inf, ccache, predictor)
#     146             ), "rmse_inf must be in units of kJ/mol (or equivalent)"
#     147
# --> 148         self.ccache = ccache or create_compound_cache_from_zenodo()
#     149
#     150         if predictor is None:
#
# ~/anaconda3/lib/python3.8/site-packages/equilibrator_cache/api.py in create_compound_cache_from_zenodo(settings)
#      71
#      72     """
# ---> 73     path = get_cached_filepath(settings)
#      74     return create_compound_cache_from_sqlite_file(path)
#
# ...
